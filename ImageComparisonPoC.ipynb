# %%
pip install opencv-python
# Out:
# ...
#
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/a4/7d/f1c30a92854540bf789e9cd5dde7ef49bbe63f855b85a2e6b3db8135c591/opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB 960.0 kB/s eta 0:00:42
#    ---------------------------------------- 0.2/39.5 MB 1.8 MB/s eta 0:00:22
#    ---------------------------------------- 0.2/39.5 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.3/39.5 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.4/39.5 MB 2.2 MB/s eta 0:00:18
#     --------------------------------------- 0.5/39.5 MB 2.0 MB/s eta 0:00:20
#     --------------------------------------- 0.6/39.5 MB 2.2 MB/s eta 0:00:18
#     --------------------------------------- 0.7/39.5 MB 2.2 MB/s eta 0:00:18
# ...

# %%
from skimage.metrics import structural_similarity as ssim
import cv2

def compare_images(imageA, imageB):
    # Convert the images to grayscale
    grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
    grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)
    
    # Compute the Structural Similarity Index (SSI) between the two images
    score, diff = ssim(grayA, grayB, full=True)
    
    return score

# Load the two images
image1 = cv2.imread('D:/downloads/ImageComp/MagnumPic3.1.jpeg')
image2 = cv2.imread('D:/downloads/ImageComp/MagnumPic2.1.jpeg')

# Compare the images and print the similarity score
similarity_score = compare_images(image1, image2)
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 19
#      16 image2 = cv2.imread('D:/downloads/ImageComp/MagnumPic2.1.jpeg')
#      18 # Compare the images and print the similarity score
# ---> 19 similarity_score = compare_images(image1, image2)
#      20 print(f"Similarity score between the two images: {similarity_score}")
#
# Cell In[9], line 6, in compare_images(imageA, imageB)
#       4 def compare_images(imageA, imageB):
#       5     # Convert the images to grayscale
# ----> 6     grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
#       7     grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)
#       9     # Compute the Structural Similarity Index (SSI) between the two images
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
from skimage.metrics import structural_similarity as ssim
import cv2

def compare_images(imageA, imageB):
    # Convert the images to grayscale
    grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
    grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)
    
    # Compute the Structural Similarity Index (SSI) between the two images
    score, diff = ssim(grayA, grayB, full=True)
    
    return score

# Load the two images
image1 = cv2.imread(r'D:\downloads\ImageComp\MagnumPic3.jpg')
image2 = cv2.imread(r'D:\downloads\ImageComp\MagnumPic2.jpg')

# Check if images are loaded correctly
if image1 is None:
    print("Error: Image 1 could not be loaded.")
if image2 is None:
    print("Error: Image 2 could not be loaded.")

if image1 is not None and image2 is not None:
    # Compare the images and print the similarity score
    similarity_score = compare_images(image1, image2)
    print(f"Similarity score between the two images: {similarity_score}")
# Out:
# Similarity score between the two images: 0.06388886285241173

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

# Load the VGG16 model pre-trained on ImageNet
model = VGG16(weights='imagenet', include_top=False)

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(2200, 1600))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\MagnumPic3.jpg', model)
features2 = extract_features('D:\downloads\ImageComp\MagnumPic2.jpg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# Similarity score between the two images: 0.12040194869041443

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:/downloads/ImageComp/MagnumPic3.jpg')
img2 = Image.open('D:/downloads/ImageComp/MagnumPic2.jpg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Swim1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('Swim2.jpg')
ax2.axis('off')

plt.show()
# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\MagnumPic3.jpg', model)
features2 = extract_features('D:\downloads\ImageComp\MagnumPic2.jpg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Similarity score between the two images: 0.9792493581771851

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features
# Load the images
img1 = Image.open('D:\downloads\ImageComp\meridian1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\meridien3.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('MagnumPic3.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('MagnumPic2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Similarity score between the two images: 0.6789659261703491

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features
# Load the images
img1 = Image.open('D:\\downloads\\ImageComp\\room1A.png')
img2 = Image.open('D:\\downloads\\ImageComp\\room2A.png')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('MagnumPic3.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('MagnumPic2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features('D:\\downloads\\ImageComp\\room1A.png', model)
features2 = extract_features('D:\\downloads\\ImageComp\\room2A.png', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Similarity score between the two images: 0.767412006855011

# %%
from PIL import Image

try:
    img1 = Image.open(r'C:\Users\mmt9823\Pictures\Screenshots\SA1.jpeg')
    img1.show()
except FileNotFoundError as e:
    print(f"File not found: {e}")
# Out:
# File not found: [Errno 2] No such file or directory: 'C:\\Users\\mmt9823\\Pictures\\Screenshots\\SA1.jpeg'

# %%
C:\Users\mmt9823\Pictures\Screenshots\Screenshot (179)

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\meridian1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\meridien3.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('MagnumPic3.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('MagnumPic2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Similarity score between the two images: 0.6789659261703491

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\ginger1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\ginger2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Ginger1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('Ginger2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\ginger2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\ginger1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Similarity score between the two images: 0.7132307887077332

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features
# Load the images
img1 = Image.open('D:/downloads/ImageComp/room1.jpg')
img2 = Image.open('D:/downloads/ImageComp/room2.jpg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('room1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('room2.jpg')
ax2.axis('off')

plt.show()

# Load the InceptionV3 model pre-trained on ImageNet


# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\room1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\room2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Similarity score between the two images: 0.8387798070907593

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features


# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\entrance1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\entrance2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('entrance1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('entrance2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\entrance2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\ginger1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\ginger2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Ginger1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('Ginger2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\ginger2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\ginger1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\meridian1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\meridien3.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('MagnumPic3.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('MagnumPic2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Similarity score between the two images: 0.8359928727149963

# %%
# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\swim2.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\swimm1.jpeg', model)

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\swimm1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\swim2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Swim1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('Swim2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\swim2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\swimm1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Similarity score between the two images: 0.7748344540596008

# %%
features1 = extract_features('D:\downloads\ImageComp\ginger1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\ginger2.jpeg', model)

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\ginger1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\ginger2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Ginger1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('Ginger2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\ginger2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\ginger1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Similarity score between the two images: 0.9827322959899902

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\ginger1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\ginger2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Ginger1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('Ginger2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\ginger2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\ginger1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Similarity score between the two images: 0.6814899444580078

# %%
# Extract features from the two images
features1 = extract_features('D:/downloads/ImageComp/room1.jpg', model)
features2 = extract_features('D:/downloads/ImageComp/room2.jpg', model)

# %%
print("Cat")
# Out:
# Cat

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Load the images
img1 = Image.open('D:\downloads\ImageComp\entrance1.jpeg')
img2 = Image.open('D:\downloads\ImageComp\entrance2.jpeg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('entrance1.jpg')
ax1.axis('off')

ax2.imshow(img2)
ax2.set_title('entrance2.jpg')
ax2.axis('off')

plt.show()

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\entrance2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Similarity score between the two images: 0.6915736794471741

# %%
# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\entrance2.jpeg', model)

# %% [markdown]
# # Load the InceptionV3 model pre-trained on ImageNet
# model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')
#
# def extract_features(img_path, model):
#     img = image.load_img(img_path, target_size=(299, 299))
#     img_data = image.img_to_array(img)
#     img_data = np.expand_dims(img_data, axis=0)
#     img_data = preprocess_input(img_data)
#     features = model.predict(img_data)
#     return features
#
# # Load the images
# img1 = Image.open('D:/downloads/ImageComp/room1.jpg')
# img2 = Image.open('D:/downloads/ImageComp/room2.jpg')
#
# # Display the images
# fig, (ax1, ax2) = plt.subplots(1, 2)
# ax1.imshow(img1)
# ax1.set_title('room1.jpg')
# ax1.axis('off')
#
# ax2.imshow(img2)
# ax2.set_title('room2.jpg')
# ax2.axis('off')
#
# plt.show()
#
# # Extract features from the two images
# features1 = extract_features(r'D:/downloads/ImageComp/room1.jpg', model)
# features2 = extract_features(r'D:/downloads/ImageComp/room2.jpg', model)
#
# # Compute the similarity score (e.g., using cosine similarity)
# similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
# print(f"Similarity score between the two images: {similarity_score}")

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Similarity score between the two images: 0.6789659261703491

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\meridian2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Similarity score between the two images: 0.6333720684051514

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\meridian2.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Similarity score between the two images: 0.6564164757728577

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\swim2.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\swimm1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Similarity score between the two images: 0.747776448726654

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\ginger1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\ginger2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Similarity score between the two images: 0.7132307887077332

# %%
entrance1

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\entrance2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Similarity score between the two images: 0.6488447785377502

# %%
room1A room2A

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:/downloads/ImageComp/room1.jpg', model)
features2 = extract_features('D:/downloads/ImageComp/room2.jpg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Similarity score between the two images: 0.837723970413208

# %%
room1A  room2A

# %%
# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:/downloads/ImageComp/room1A.jpeg', model)
features2 = extract_features('D:/downloads/ImageComp/room2A.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Similarity score between the two images: 0.767034113407135

# %%
Inception V3

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np

# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\room1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\room2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Similarity score between the two images: 0.8525770306587219

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\meridian2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Similarity score between the two images: 0.7737644910812378

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\meridian1.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Similarity score between the two images: 0.8346459865570068

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\meridian2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Similarity score between the two images: 0.8070477247238159

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\ginger1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\ginger2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Similarity score between the two images: 0.9529263377189636

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\entrance2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Similarity score between the two images: 0.9087366461753845

# %%
# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\swim2.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\swimm1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")

# %%
EfficientNet

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input
import numpy as np

# Load the EfficientNetB0 model pre-trained on ImageNet
model = EfficientNetB0(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\room1.jpg', model)
features2 = extract_features(r'D:\downloads\ImageComp\room2.jpg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Similarity score between the two images: 0.7767111659049988

# %%
# Load the EfficientNetB0 model pre-trained on ImageNet
model = EfficientNetB0(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\swim2.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\swimm1.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Similarity score between the two images: 0.759317934513092

# %%
features1 = extract_features('D:\downloads\ImageComp\ginger1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\ginger2.jpeg', model)

# %%
# Load the EfficientNetB0 model pre-trained on ImageNet
model = EfficientNetB0(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\ginger1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\ginger2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Similarity score between the two images: 0.6591333150863647

# %%
features1 = extract_features('D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\entrance2.jpeg', model)

# %%
# Load the EfficientNetB0 model pre-trained on ImageNet
model = EfficientNetB0(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features('D:\downloads\ImageComp\entrance1.jpeg', model)
features2 = extract_features('D:\downloads\ImageComp\entrance2.jpeg', model)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = np.dot(features1.flatten(), features2.flatten()) / (np.linalg.norm(features1) * np.linalg.norm(features2))
print(f"Similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Similarity score between the two images: 0.34083741903305054

# %%
import torch
from PIL import Image
from transformers import CLIPProcessor, CLIPModel

# Load the CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

def extract_features(img_path, model, processor):
    image = Image.open(img_path)
    inputs = processor(images=image, return_tensors="pt")
    features = model.get_image_features(**inputs)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\room1.jpg', model, processor)
features2 = extract_features(r'D:\downloads\ImageComp\room2.jpg', model, processor)

# Compute the similarity score (e.g., using cosine similarity)
similarity_score = torch.nn.functional.cosine_similarity(features1, features2)
print(f"Similarity score between the two images: {similarity_score.item()}")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File D:\anacondaa\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
import pandas as pd

# %%
import requests

# %%
import requests
import pandas as pd
import time
import pandas as pd
import numpy as np
import requests
import time
#import Levenshtein as lev
#from fuzzywuzzy import fuzz
import re

pd.set_option('display.max_colwidth', None)

# %%
pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26800 sha256=4d366cddb7aabcf4a00d5606f3d23c475ad3f5529395bf04d1ba81eb6df81821
#   Stored in directory: c:\users\mmt9823\appdata\local\pip\cache\wheels\68\5d\a5\edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandasql import sqldf

# %%
import sqldf

# %%
def poll_job(s, redash_url, job):
    # TODO: add timeout
    while job['status'] not in (3,4):
        response = s.get('{}/api/jobs/{}'.format(redash_url, job['id']))
        job = response.json()['job']
        time.sleep(1)
    if job['status'] == 3:
        return job['query_result_id']    
    return None

# %%
def get_fresh_query_result(redash_url, query_id, api_key):
    s = requests.Session()
    s.headers.update({'Authorization': 'Key {}'.format(api_key)})
    response = s.post('{}/api/queries/{}/refresh'.format(redash_url, query_id))
    print(response.text)
    if response.status_code != 200:
        raise Exception('Refresh failed.')
    result_id = poll_job(s, redash_url, response.json()['job'])
    if result_id:
        response = s.get('{}/api/queries/{}/results/{}.json'.format(redash_url, query_id, result_id))
        if response.status_code != 200:
            raise Exception('Failed getting results.')
    else:
        raise Exception('Query execution failed.')
    return response.json()['query_result']['data']['rows']

# %%
#reading crawls data from redash
api_key_gi = 'AetdowHcIE4x3Z7Aon7DsGnZgmtEoIpEI5KNTmsf'
vendor_properties = pd.DataFrame.from_dict(get_fresh_query_result('https://hotels-redash.mmt.live/' ,12987,api_key_gi))
print("Vendor Properties- ",vendor_properties.shape)
# Out:
# {
#   "message": "Couldn't find resource. Please login and try again."
# }
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 #reading crawls data from redash
#       2 api_key_gi = 'AetdowHcIE4x3Z7Aon7DsGnZgmtEoIpEI5KNTmsf'
# ----> 3 vendor_properties = pd.DataFrame.from_dict(get_fresh_query_result('https://hotels-redash.mmt.live/' ,12987,api_key_gi))
#       4 print("Vendor Properties- ",vendor_properties.shape)
#
# Cell In[18], line 7, in get_fresh_query_result(redash_url, query_id, api_key)
#       5 print(response.text)
#       6 if response.status_code != 200:
# ----> 7     raise Exception('Refresh failed.')
#       8 result_id = poll_job(s, redash_url, response.json()['job'])
#       9 if result_id:
#
# Exception: Refresh failed.

# %%
vendor_properties
# Out:
#      vendor_hotel_id  activation_status  \
# 0           12714268                1.0
# 1           22885963                1.0
# 2             649100                1.0
# 3           22885958                1.0
# 4           22886023                1.0
# ...              ...                ...
# 2877        44878851                1.0
# 2878        47234494                1.0
# 2879        41245629                1.0
# 2880        49685203                1.0
# 2881        45593661                1.0
#
#                                                                                                                  vendor_address  \
# 0                                                                                       po,kuttanad taluk,alleppey,india,688505
# 1        swargadwar road, opposite of birla guest house, goudabad sahi, puri, odisha, india 752001,baliapanda,puri,india,752001
# ...

# %%
#reading crawls data from redash
api_key_gi = '7k07SN8ZqbBGbkBhy4vk0qeDP4NGe8meXPJmgwNm'
vendor_properties = pd.DataFrame.from_dict(get_fresh_query_result('https://hotels-redash.mmt.live/',12987,api_key_gi))
print("Vendor Properties- ",vendor_properties.shape)
# Out:
# {"job": {"status": 1, "error": "", "id": "3fc68718-107e-4637-bedd-ec7922fed0e7", "query_result_id": null, "updated_at": 0}}
# Vendor Properties-  (1, 1)

# %%
vendor_properties
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
#reading crawls data from redash
api_key_gi = 'AetdowHcIE4x3Z7Aon7DsGnZgmtEoIpEI5KNTmsf'
vendor_properties = pd.DataFrame.from_dict(get_fresh_query_result('http://common-redash.mmt.com/' ,67865,api_key_gi))
print("Vendor Properties- ",vendor_properties.shape)
# Out:
# {"job": {"status": 1, "error": "", "id": "0cc45893-452a-4bcb-b99f-68a665533be6", "query_result_id": null, "updated_at": 0}}
# Vendor Properties-  (2882, 7)

# %%
vendor_properties
# Out:
#      vendor_hotel_id  activation_status  \
# 0           23725479                1.0
# 1           24109127                1.0
# 2            6602863                1.0
# 3            1020851                1.0
# 4            1016053                1.0
# ...              ...                ...
# 2877        40213870                1.0
# 2878        35510592                1.0
# 2879        42542829                1.0
# 2880        41487708                1.0
# 2881        41658231                1.0
#
#                                                                                                                vendor_address  \
# 0                                                                        baba sahib chowk,golden temple,amritsar,india,143006
# 1                                              town hall, golghar, town hall road, gorakhpur,gorakhpur,gorakhpur,india,273001
# ...

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
from scipy.spatial.distance import cosine
import numpy as np

# Load the InceptionV3 model pre-trained on ImageNet
model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')


def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(299, 299))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features

# Extract features from the two images
features1 = extract_features(r'D:\downloads\ImageComp\meridian2.jpeg', model)
features2 = extract_features(r'D:\downloads\ImageComp\meridien3.jpeg', model)

# Compute cosine similarity using SciPy
similarity_score = 1 - cosine(features1.flatten(), features2.flatten())
print(f"Cosine similarity score between the two images: {similarity_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Cosine similarity score between the two images: 0.7553613927527714
